# %%
from langgraph.graph import StateGraph

# %%
print("hello")
# Out:
# hello

# %%
print("hello, tell if there is any error due to python version")
# Out:
# hello, tell if there is any error due to python version

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
